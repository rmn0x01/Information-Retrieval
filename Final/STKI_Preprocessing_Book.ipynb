# %%
import pandas as pd
import numpy as np
import nltk
nltk.download('punkt')
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import LancasterStemmer
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
df = pd.read_excel('databook.xlsx')
df.columns=['Wikipedia article ID',
           'Freebase ID',
           'Book title',
           'Author',
           'Date',
           'Genres ID',
            'Genres',
           'Summary']
df
# Out:
#       Wikipedia article ID Freebase ID  \
# 0                      843     /m/0k36
# 1                      986     /m/0ldx
# 2                     1756     /m/0sww
# 3                     2080     /m/0wkt
# 4                     2152     /m/0x5g
# 5                     2890    /m/011zx
# 6                     2950    /m/012dq
# 7                     4081    /m/01b4w
# 8                     4082    /m/01b56
# 9                     4331    /m/01d3j
# 10                    4332    /m/01d40
# 11                    4376    /m/01dlg
# 12                    4381    /m/01dnz
# 13                    4382    /m/01dpg
# 14                    4386    /m/01dqt
# 15                    4449    /m/01f8p
# 16                    4451    /m/01f9l
# 17                    4452    /m/01fb1
# 18                    4454    /m/01fby
# 19                    6020    /m/01t5z
# 20                    6628    /m/01y92
# 21                    6629    /m/01y9j
# 22                    6630    /m/01yb0
# ...

# %%
to_drop = ['Wikipedia article ID','Freebase ID', 'Genres ID','Date'] #drop column
df.drop(to_drop, inplace = True, axis = 1)
df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-202971718aac> in <module>
#       1 to_drop = ['Wikipedia article ID','Freebase ID', 'Genres ID','Date'] #drop column
# ----> 2 df.drop(to_drop, inplace = True, axis = 1)
#       3 df.head()
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3938                                            index=index, columns=columns,
#    3939                                            level=level, inplace=inplace,
# -> 3940                                            errors=errors)
#    3941
#    3942     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3778         for axis, labels in axes.items():
# ...

# %%
df=df.dropna() #drop data NaN
df
# Out:
#                                               Book title  \
# 0                                     A Clockwork Orange
# 1                                             The Plague
# 3                                   A Fire Upon the Deep
# 4                         All Quiet on the Western Front
# 5                                   A Wizard of Earthsea
# 7                        Blade Runner 3: Replicant Night
# 8                      Blade Runner 2: The Edge of Human
# 19                                                 Crash
# 20                                      Children of Dune
# 21                               Candide, ou l'Optimisme
# 22                                     Chapterhouse Dune
# 23                                              Carmilla
# 24                                 The Cider House Rules
# 25                                               Dracula
# 26                                           Don Quixote
# ...

# %%
def preprocessing(row):
    filtered_sentence = []
    stem_sentence =[]
    row = row.lower()
    words = word_tokenize(row)
    stopWords = set(stopwords.words('english'))
    lancaster=LancasterStemmer()
    for w in words:
        if w not in stopWords: #stopword
            filtered_sentence.append(w)
            stem_sentence.append(lancaster.stem(w)+" ")
    return "".join(stem_sentence)

# %%
outSummary=[]
for row in df['Summary']:
    outSummary.append(preprocessing(row))

# %%
outSummary[0]
# Out:
# "alex , teen liv near-future england , lead gang night orgy opportun , random `` ultra-violence . '' alex 's friend ( `` droog '' novel 's anglo-russian slang , nads ) : dim , slow-witted bru gang 's musc ; georgy , amb second-in-command ; pet , most play along droog indulg tast ultra-violence . charact sociopa hard juvenil delinqu , alex also intellig quick-witted , soph tast mus , particul fond beethov , `` lov ludwig van . '' novel begin droog sit favorit hangout ( korov milkb ) , drink milk-drug cocktail , cal `` milk-plus '' , hyp night 's mayhem . assault scholar walk hom publ libr , rob stor leav own wif bloody unconscy , stomp panhandl derelict , scuffl riv gang . joyrid countrysid stol car , break isol cot maul young coupl liv , beat husband rap wif . metafict touch , husband writ work manuscrib cal `` clockwork orang , '' alex contemptu read paragraph stat novel 's main them shredding manuscrib . back milk bar , alex pun dim crud behavio , strains within gang becom app . ho
# ...

# %%
import csv
csv.writer(outSummary, delimiter=";")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-59-b557b21dcb8c> in <module>
# ----> 1 for index,row in outSummary:
#       2     data['Summary'][index]=row
#
# ValueError: too many values to unpack (expected 2)

# %%
data
